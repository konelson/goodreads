# %%
pwd
# Out:
# '/Users/kelly/metis_v3/Project_5'

# %%
import ggplot

from ggplot import *

# %%
import pandas as pd

# %%
book_df = pd.read_csv('books.csv')
ratings_df = pd.read_csv('ratings.csv')
booktags_df = pd.read_csv('booktags.csv')
tags_df = pd.read_csv('tags.csv')

# %% [markdown]
# # EDA

# %%
book_df.head()
# Out:
#    book_id  goodreads_book_id  best_book_id  work_id  books_count       isbn  \
# 0        1            2767052       2767052  2792775          272  439023483
# 1        2                  3             3  4640799          491  439554934
# 2        3              41865         41865  3212258          226  316015849
# 3        4               2657          2657  3275794          487   61120081
# 4        5               4671          4671   245494         1356  743273567
#
#          isbn13                      authors  original_publication_year  \
# 0  9.780439e+12              Suzanne Collins                     2008.0
# 1  9.780440e+12  J.K. Rowling, Mary GrandPré                     1997.0
# 2  9.780316e+12              Stephenie Meyer                     2005.0
# 3  9.780061e+12                   Harper Lee                     1960.0
# 4  9.780743e+12          F. Scott Fitzgerald                     1925.0
#
#                              original_title  \
# ...

# %%
book_df.columns
# Out:
# Index(['book_id', 'goodreads_book_id', 'best_book_id', 'work_id',
#        'books_count', 'isbn', 'isbn13', 'authors', 'original_publication_year',
#        'original_title', 'title', 'language_code', 'average_rating',
#        'ratings_count', 'work_ratings_count', 'work_text_reviews_count',
#        'ratings_1', 'ratings_2', 'ratings_3', 'ratings_4', 'ratings_5',
#        'image_url', 'small_image_url'],
#       dtype='object')

# %%
ratings_df.head()
# Out:
#    user_id  book_id  rating
# 0        1      258       5
# 1        2     4081       4
# 2        2      260       5
# 3        2     9296       5
# 4        2     2318       3

# %%
booktags_df[booktags_df.goodreads_book_id==1].head()
# Out:
#    goodreads_book_id  tag_id   count
# 0                  1   30574  167697
# 1                  1   11305   37174
# 2                  1   11557   34173
# 3                  1    8717   12986
# 4                  1   33114   12716

# %%
tags_df.shape
# Out:
# (34252, 3)

# %%
tags_df['tag_name'][100]
# Out:
# '02-to-read-speculative-fiction'

# %%
tags_df['tag_name'][100].split('-')
# Out:
# ['02', 'to', 'read', 'speculative', 'fiction']

# %%
tags_df[20000:20150]
# Out:
#        tag_id                             tag_name  \
# 20000   20000                    midnight-in-paris
# 20001   20001                         midnight-sun
# 20002   20002                       midnight-texas
# 20003   20003                midnight-texas-series
# 20004   20004                          midnighters
# 20005   20005                   midnighters-series
# 20006   20006                              midwest
# 20007   20007                              midwife
# 20008   20008                            midwifery
# 20009   20009             midwifery-and-childbirth
# 20010   20010                      midwifery-books
# 20011   20011                             midwives
# 20012   20012                      mieskirjailijat
# 20013   20013                             mieville
# 20014   20014                            might-buy
# 20015   20015                           might-read
# 20016   20016                              mignola
# ...

# %%
import ggplot
# Out:
# /anaconda3/lib/python3.6/site-packages/ggplot/utils.py:81: FutureWarning: pandas.tslib is deprecated and will be removed in a future version.
# You can access Timestamp as pandas.Timestamp
#   pd.tslib.Timestamp,

# %%
from ggplot import *

# %%
ratings_df.head()
# Out:
#    user_id  book_id  rating
# 0        1      258       5
# 1        2     4081       4
# 2        2      260       5
# 3        2     9296       5
# 4        2     2318       3

# %%
ratings_df[ratings_df['user_id'] ==1].rating.count()
# Out:
# 117

# %%
ratings_df.shape
# Out:
# (5976479, 3)

# %%
ratings_df.head()
# Out:
#    user_id  book_id  rating
# 0        1      258       5
# 1        2     4081       4
# 2        2      260       5
# 3        2     9296       5
# 4        2     2318       3

# %%
ratings_per_user = ratings_df.groupby(by = 'user_id', as_index = False)[['rating']].count()

# %%
ratings_per_user
# Out:
#        user_id  rating
# 0            1     117
# 1            2      65
# 2            3      91
# 3            4     134
# 4            5     100
# 5            6      90
# 6            7     155
# 7            8      98
# 8            9     132
# 9           10     128
# 10          11     120
# 11          12     113
# 12          13      96
# 13          14     108
# 14          15      97
# 15          16      68
# 16          17      61
# 17          18     109
# 18          19     119
# 19          20      90
# 20          21      61
# 21          22     120
# 22          23     127
# 23          24     128
# 24          25      60
# 25          26     103
# 26          27     121
# 27          28     120
# 28          29      98
# 29          30      92
# ...        ...     ...
# 53394    53395      94
# 53395    53396      96
# 53396    53397      97
# 53397    53398     110
# 53398    53399     101
# 53399    53400     123
# 53400    53401     128
# 53401    53402     100
# ...

# %%
ratings_df.head()
# Out:
#    user_id  book_id  rating
# 0        1      258       5
# 1        2     4081       4
# 2        2      260       5
# 3        2     9296       5
# 4        2     2318       3

# %%
ratings_per_user.rename(columns = {"rating": "Number of Ratings"}, inplace = True)

# %%
#Ratings per User

ggplot(aes(x='Number of Ratings'), data=ratings_per_user) + \
    geom_histogram(fill = 'darkslategrey', color = 'slategrey')
# Out:
# <ggplot: (-9223372036544296753)>

# %%
qplot(ratings_per_user['Number of Ratings'])
# Out:
# <ggplot: (308899504)>

# %%
ratings_df.groupby(by = 'rating').count()
# Out:
#         user_id  book_id
# rating
# 1        124195   124195
# 2        359257   359257
# 3       1370916  1370916
# 4       2139018  2139018
# 5       1983093  1983093

# %%
ratings_df.rating.unique()
# Out:
# array([5, 4, 3, 2, 1])

# %%
#Distribution of Ratings

ggplot(aes(x='rating'), data=ratings_df) + \
    geom_bar(fill = 'darkslategrey', color = 'slategrey') #+ scale_x_continuous(breaks=(0,5,1))
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/patches.py:83: UserWarning:
#
# Setting the 'color' property will overridethe edgecolor or facecolor properties.
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/patches.py:83: UserWarning:
#
# Setting the 'color' property will overridethe edgecolor or facecolor properties.
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/patches.py:83: UserWarning:
#
# Setting the 'color' property will overridethe edgecolor or facecolor properties.
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/patches.py:83: UserWarning:
#
# Setting the 'color' property will overridethe edgecolor or facecolor properties.
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/patches.py:83: UserWarning:
#
# Setting the 'color' property will overridethe edgecolor or facecolor properties.
# <ggplot: (305141680)>

# %%
#Distribution of Ratings

qplot(ratings_df.rating) 
  #  geom_histogram(x = 'rating', fill = 'darkslategrey', color = 'slategrey')
# Out:
# <ggplot: (295526306)>

# %%
tags_df.head()
# Out:
#    tag_id tag_name
# 0       0        -
# 1       1     --1-
# 2       2    --10-
# 3       3    --12-
# 4       4   --122-

# %%
tags_df['tag_words'] = tags_df.tag_name.apply(lambda x: x.split('-'))

# %%
tags_df.head()
# Out:
#    tag_id tag_name    tag_words
# 0       0        -         [, ]
# 1       1     --1-    [, , 1, ]
# 2       2    --10-   [, , 10, ]
# 3       3    --12-   [, , 12, ]
# 4       4   --122-  [, , 122, ]

# %%
ratings %>% 
  group_by(user_id) %>% 
  summarize(number_of_ratings_per_user = n()) %>% 
  ggplot(aes(number_of_ratings_per_user)) + 
  geom_bar(fill = "cadetblue3", color = "grey20") + coord_cartesian(c(3, 50))

# %%
tags_df[1000:1200]
# Out:
#       tag_id                             tag_name  \
# 1000    1000                  3-mystery-thrillers
# 1001    1001                             3-poetry
# 1002    1002                       3-read-fiction
# 1003    1003                      3-short-stories
# 1004    1004                 3-sigma-force-series
# 1005    1005        3-sisters-ranch-barrel-racing
# 1006    1006                             3-sports
# 1007    1007                               3-star
# 1008    1008                         3-star-books
# 1009    1009                         3-star-shelf
# 1010    1010                              3-stars
# 1011    1011            3-stars-we-can-be-friends
# 1012    1012                        3-to-read-low
# 1013    1013                               3-نجوم
# 1014    1014                         30-before-30
# 1015    1015           30-book-campaign-7th-grade
# 1016    1016                         30-book-goal
# 1017    1017  30-books-every-man-should-read-by-3
# ...

# %%
booktags_df
# Out:
#         goodreads_book_id  tag_id   count
# 0                       1   30574  167697
# 1                       1   11305   37174
# 2                       1   11557   34173
# 3                       1    8717   12986
# 4                       1   33114   12716
# 5                       1   11743    9954
# 6                       1   14017    7169
# 7                       1    5207    6221
# 8                       1   22743    4974
# 9                       1   32989    4364
# 10                      1   27199    3857
# 11                      1   11590    3456
# 12                      1   18886    3374
# 13                      1    6953    2408
# 14                      1   22753    1881
# 15                      1   24960    1821
# 16                      1    1691    1742
# 17                      1    6857    1560
# 18                      1   15965    1309
# 19                      1    6888    1095
# 20                      1   26785    1093
# ...

# %%
book_df.shape
# Out:
# (10000, 23)

# %%
book_df[:1]
# Out:
#    book_id  goodreads_book_id  best_book_id  work_id  books_count       isbn  \
# 0        1            2767052       2767052  2792775          272  439023483
#
#          isbn13          authors  original_publication_year    original_title  \
# 0  9.780439e+12  Suzanne Collins                     2008.0  The Hunger Games
#
#                          ...                         ratings_count  \
# 0                        ...                               4780653
#
#   work_ratings_count  work_text_reviews_count  ratings_1  ratings_2  \
# 0            4942365                   155254      66715     127936
#
#    ratings_3  ratings_4  ratings_5  \
# 0     560092    1481305    2706317
#
#                                            image_url  \
# 0  https://images.gr-assets.com/books/1447303603m...
#
#                                      small_image_url
# 0  https://images.gr-assets.com/books/1447303603s...
#
# [1 rows x 23 columns]

# %%
booktags_df[booktags_df.goodreads_book_id ==2767052]
# Out:
#         goodreads_book_id  tag_id  count
# 619294            2767052   11557  50755
# 619295            2767052    8717  35418
# 619296            2767052   33114  25968
# 619297            2767052   11743  13819
# 619298            2767052   10064  12985
# 619299            2767052   30574  11314
# 619300            2767052   10059  11065
# 619301            2767052   11305  10836
# 619302            2767052   32989  10823
# 619303            2767052   26837   8772
# 619304            2767052    5207   7100
# 619305            2767052   26771   6211
# 619306            2767052   27199   5094
# 619307            2767052   22743   4904
# 619308            2767052   11590   4194
# 619309            2767052   26138   3341
# 619310            2767052    1691   3190
# 619311            2767052   15081   2899
# 619312            2767052    4949   2010
# 619313            2767052   17213   1985
# 619314            2767052   29452   1776
# 619315            2767052   25148   1478
# ...

# %%
tags_and_desc = booktags_df.join(tags_df, on = ['tag_id'], how = 'left', lsuffix = '1')#.goodreads_book_id ==1]

# %%
#Hunger Games
tags_and_desc[tags_and_desc.goodreads_book_id ==2767052]
# Out:
#         goodreads_book_id  tag_id1  count  tag_id             tag_name  \
# 619294            2767052    11557  50755   11557            favorites
# 619295            2767052     8717  35418    8717    currently-reading
# 619296            2767052    33114  25968   33114          young-adult
# 619297            2767052    11743  13819   11743              fiction
# 619298            2767052    10064  12985   10064            dystopian
# 619299            2767052    30574  11314   30574              to-read
# 619300            2767052    10059  11065   10059             dystopia
# 619301            2767052    11305  10836   11305              fantasy
# 619302            2767052    32989  10823   32989                   ya
# 619303            2767052    26837   8772   26837      science-fiction
# 619304            2767052     5207   7100    5207          books-i-own
# 619305            2767052    26771   6211   26771               sci-fi
# ...

# %%
#Harry Potter
tags_and_desc[tags_and_desc.goodreads_book_id ==1]
# Out:
#     goodreads_book_id  tag_id1   count  tag_id                 tag_name  \
# 0                   1    30574  167697   30574                  to-read
# 1                   1    11305   37174   11305                  fantasy
# 2                   1    11557   34173   11557                favorites
# 3                   1     8717   12986    8717        currently-reading
# 4                   1    33114   12716   33114              young-adult
# 5                   1    11743    9954   11743                  fiction
# 6                   1    14017    7169   14017             harry-potter
# 7                   1     5207    6221    5207              books-i-own
# 8                   1    22743    4974   22743                    owned
# 9                   1    32989    4364   32989                       ya
# 10                  1    27199    3857   27199                   series
# 11                  1    11590    3456   11590               favourites
# ...

# %%
book_df[book_df.goodreads_book_id.isin(hp_tag_list)]
# Out:
#       book_id  goodreads_book_id  best_book_id   work_id  books_count  \
# 1           2                  3             3   4640799          491
# 17         18                  5             5   2402163          376
# 20         21                  2             2   2809203          307
# 22         23              15881         15881   6231171          398
# 23         24                  6             6   3046572          332
# 24         25             136251        136251   2963218          263
# 26         27                  1             1  41335427          275
# 278       279           29056083      29056083  48765776           95
# 341       342           13497818      13497818  19926990          139
# 398       399            3950967       3950967   3007490          131
# 421       422             862041        862041   2962492           76
# 468       469              41899         41899   4195128          123
# ...

# %%
book_df.shape
# Out:
# (10000, 23)

# %%
hp_tag_list = list(tags_and_desc[tags_and_desc.tag_id == 14017].goodreads_book_id)

# %%
book_df[book_df.goodreads_book_id.isin(hp_tag_list)].original_title
# Out:
# 1                Harry Potter and the Philosopher's Stone
# 17               Harry Potter and the Prisoner of Azkaban
# 20              Harry Potter and the Order of the Phoenix
# 22                Harry Potter and the Chamber of Secrets
# 23                    Harry Potter and the Goblet of Fire
# 24                   Harry Potter and the Deathly Hallows
# 26                 Harry Potter and the Half-Blood Prince
# 278     Harry Potter and the Cursed Child, Parts One a...
# 341                                    The Casual Vacancy
# 398                          The Tales of Beedle the Bard
# 421                       Complete Harry Potter Boxed Set
# 468               Fantastic Beasts and Where to Find Them
# 1285                           Quidditch Through the Ages
# 2000                          Harry Potter: Film Wizardry
# 2100                     Harry Potter Boxed Set Books 1-4
# 3053    Harry Potter and the Chamber of Secrets: Sheet...
# ...

# %%
genre_list = ["football"]
tags_df[tags_df.tag_name.isin(genre_list)]
# Out:
#        tag_id  tag_name     tag_words
# 12281   12281  football  ['football']

# %%
genre_list=["art", "biography", "business", "chicklit", "childrens", "christian", "classics",
            "comics", "contemporary", "cookbooks", "crime", "ebooks", "fantasy", "fiction", "gay", "lesbian",
            "graphicnovels","history", "historicalfiction", "horror", "humor", "comedy","manga", "memoir", 
            "music", "mystery", "nonfiction", "paranormal", "philosophy", "poetry", "psychology", "religion", 
            "romance", "science","sciencefiction", "shortstories","suspense", "spirituality", "sports", "thriller", "travel", "youngadult"]

# %%
len(genre_list)
# Out:
# 42

# %%
tags_df[tags_df.tag_name.isin(genre_list)]
# Out:
#        tag_id           tag_name              tag_words
# 2938     2938                art                ['art']
# 4605     4605          biography          ['biography']
# 5951     5951           business           ['business']
# 6766     6766           chicklit           ['chicklit']
# 6953     6953          childrens          ['childrens']
# 7077     7077          christian          ['christian']
# 7457     7457           classics           ['classics']
# 7725     7725             comedy             ['comedy']
# 7778     7778             comics             ['comics']
# 8055     8055       contemporary       ['contemporary']
# 8150     8150          cookbooks          ['cookbooks']
# 8517     8517              crime              ['crime']
# 10210   10210             ebooks             ['ebooks']
# 11305   11305            fantasy            ['fantasy']
# 11743   11743            fiction            ['fiction']
# 12874   12874                gay                ['gay']
# ...

# %%
genre_df = booktags_df.join(tags_df, on = 'tag_id', lsuffix = 'tag_id')[
    booktags_df.join(tags_df, on = 'tag_id', lsuffix = 'tag_id').tag_name.isin(genre_list)]

# %%
(genre_df.groupby(by = 'tag_name', as_index = False).count()[['tag_name', 'tag_id']])
# Out:
#              tag_name  tag_id
# 0                 art     436
# 1           biography    1109
# 2            business     377
# 3            chicklit     563
# 4           childrens    1354
# 5           christian     357
# 6            classics    2785
# 7              comedy    1031
# 8              comics     469
# 9        contemporary    5287
# 10          cookbooks      92
# 11              crime    2083
# 12             ebooks    7203
# 13            fantasy    4259
# 14            fiction    9097
# 15                gay     100
# 16      graphicnovels     229
# 17  historicalfiction     210
# 18            history    2138
# 19             horror    1372
# 20              humor    2161
# 21            lesbian      42
# 22              manga     196
# 23             memoir     905
# 24              music     226
# 25            mystery    3686
# 26         nonfiction    1833
# 27         paranormal    1941
# 28         philosophy    1055
# 29             poetry     377
# ...

# %%
ratings_df.user_id.nunique()
# Out:
# 53424

# %%
ggplot(aes(reorder(tag_name, percentage), percentage, fill = percentage)) + geom_bar(stat = "identity") + coord_flip() + scale_fill_distiller(palette = 'YlOrRd') + labs(y = 'Percentage', x = 'Genre')
